# %%
# Voir le mouvement des communes depuis 1948


import pandas as pd

df = pd.read_csv("../src/assets/insee/v_mvt_commune_2024.csv")

# %%
df

# %%
df.groupby(["TYPECOM_AP"]).size()
# Out:
# TYPECOM_AP
# ARM       20
# COM     9695
# COMA    1047
# COMD    2522
# dtype: int64
