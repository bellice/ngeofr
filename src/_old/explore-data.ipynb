# %%
# Voir le mouvement des communes depuis 1948


import pandas as pd

df = pd.read_csv("./assets/banatic/D01-2024-01-01-liste-groupement.csv", sep='\t')

# %%
df
# Out:
#                           Région siège    Département siège  \
# 84 - Auvergne-Rhône-Alpes     01 - Ain           4 - Nantua
# 84 - Auvergne-Rhône-Alpes     01 - Ain  2 - Bourg-en-Bresse
# 84 - Auvergne-Rhône-Alpes     01 - Ain              3 - Gex
# 84 - Auvergne-Rhône-Alpes     01 - Ain           4 - Nantua
# 84 - Auvergne-Rhône-Alpes     01 - Ain           1 - Belley
# ...                                ...                  ...
# 84 - Auvergne-Rhône-Alpes     01 - Ain           4 - Nantua
# 84 - Auvergne-Rhône-Alpes     01 - Ain  2 - Bourg-en-Bresse
# 84 - Auvergne-Rhône-Alpes     01 - Ain           4 - Nantua
# 84 - Auvergne-Rhône-Alpes     01 - Ain              3 - Gex
# 84 - Auvergne-Rhône-Alpes     01 - Ain           1 - Belley
#
#                                   Arrondissement siège  Commune siège  \
# 84 - Auvergne-Rhône-Alpes          210102836 - Oyonnax      200042935
# 84 - Auvergne-Rhône-Alpes  210100533 - Bourg-en-Bresse      200071751
# ...

# %%
df.groupby(["Nom du groupement"]).size()
# Out:
# Nom du groupement
# CA        3
# CC       11
# SIVOM     7
# SIVU     33
# SMF      24
# SMO       7
# dtype: int64
